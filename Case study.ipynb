# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Case study.csv")

# %%
df.head()
# Out:
#   Subscription_Type Board  Grade Grade & Board Payment_Type  Instalment Paid  \
# 0       Pro Classic  ICSE      8         ICSE8         BULK              NaN
# 1              Pro+  NEET     11        NEET11         BULK              NaN
# 2          Pro Lite  CBSE      8         CBSE8   INSTALMENT              2.0
# 3       Pro Classic   JEE     12         JEE12   INSTALMENT              2.0
# 4       Pro Classic  NEET     12        NEET12   INSTALMENT              9.0
#
#   Payment_type   I am a  How likely are you to recommend us to a friend  \
# 0         BULK  Student                                               7
# 1         BULK  Student                                              10
# 2      Post I2  Student                                              10
# 3      Post I2  Student                                               0
# 4      Post I2  Student                                               9
#
#    Master Teachers experience  ...  wiingy website/app experience  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Subscription_Type                                                               324 non-null    object
#  1   Board                                                                           324 non-null    object
#  2   Grade                                                                           324 non-null    int64
#  3   Grade & Board                                                                   324 non-null    object
#  4   Payment_Type                                                                    324 non-null    object
#  5   Instalment Paid                                                                 168 non-null    float64
# ...

# %%
# filling nan values with zero
df.fillna(0, inplace = True)

# %%
df
# Out:
#     Subscription_Type     Board  Grade Grade & Board Payment_Type  \
# 0         Pro Classic      ICSE      8         ICSE8         BULK
# 1                Pro+      NEET     11        NEET11         BULK
# 2            Pro Lite      CBSE      8         CBSE8   INSTALMENT
# 3         Pro Classic       JEE     12         JEE12   INSTALMENT
# 4         Pro Classic      NEET     12        NEET12   INSTALMENT
# ..                ...       ...    ...           ...          ...
# 319          Pro Lite      CBSE     10        CBSE10         BULK
# 320          Pro Lite      CBSE      9         CBSE9   INSTALMENT
# 321       Pro Classic      NEET     11        NEET11   INSTALMENT
# 322          Pro Lite  Commerce     12    Commerce12         BULK
# 323          Pro Lite      CBSE      8         CBSE8   INSTALMENT
#
#      Instalment Paid Payment_type   I am a  \
# 0                0.0         BULK  Student
# 1                0.0         BULK  Student
# ...

# %%
df.describe()
# Out:
#             Grade  Instalment Paid  \
# count  324.000000       324.000000
# mean    10.219136         2.716049
# std      1.739579         3.663001
# min      4.000000         0.000000
# 25%      9.000000         0.000000
# 50%     11.000000         1.500000
# 75%     11.000000         4.000000
# max     13.000000        19.000000
#
#        How likely are you to recommend us to a friend  \
# count                                      324.000000
# mean                                         8.422840
# std                                          2.348223
# min                                          0.000000
# 25%                                          8.000000
# 50%                                          9.000000
# 75%                                         10.000000
# max                                         10.000000
#
#        Master Teachers experience  Live Class experience  \
# count                  324.000000             324.000000
# ...

# %%
df.isnull().sum()
# Out:
# Subscription_Type                                                                 0
# Board                                                                             0
# Grade                                                                             0
# Grade & Board                                                                     0
# Payment_Type                                                                      0
# Instalment Paid                                                                   0
# Payment_type                                                                      0
# I am a                                                                            0
# How likely are you to recommend us to a friend                                    0
# Master Teachers experience                                                        0
# Live Class experience                                                             0
# ...

# %%
# data visualization

df.hist(figsize = (12,12));
plt.show()

# %%
df.Subscription_Type.value_counts().plot(kind = 'bar',figsize = (12,6));

# %%
plt.figure(figsize = (12,6))
plt.title("Grades of Student")
          
sns.countplot(df.Grade);
# Out:
# C:\Users\91755\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Subscription_Type                                                               324 non-null    object
#  1   Board                                                                           324 non-null    object
#  2   Grade                                                                           324 non-null    int64
#  3   Grade & Board                                                                   324 non-null    object
#  4   Payment_Type                                                                    324 non-null    object
#  5   Instalment Paid                                                                 324 non-null    float64
# ...

# %%
df.Board.value_counts().plot(kind = 'bar');

# %%
df.rename(columns = {'Overall Course experience' : 'Overall_Course_experience'} , inplace = True)

# %%
sns.countplot(df.Overall_Course_experience);
# Out:
# C:\Users\91755\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.rename(columns = {'wiingy website/app experience' : 'wiingy_website_app_experience'}, inplace = True)
sns.countplot(df.wiingy_website_app_experience);
# Out:
# C:\Users\91755\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Key insights 

# Most of students recommend pro lite subcription to other students( almost  44% )

# Most number of students are coming from CBSE board and 11th grade has most number of students(almost 31%)

# 46% students marked no issues with master teachers where as 15% of students marked the option "Too fast in covering sylabus" 
    
# 20% of students reported they face technical isuues related to internet and faced spamming in chats

# 7% of students reported that their master doesn't connect with them regularly and also 5 % students reported that they don't know their teacher
    
# 56% students rated full rating on wiingy website experience

# More than half of students paid as installment type
