# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
survey_raw_df= pd.read_csv("survey_results_public.csv")

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
 survey = survey_raw_df.groupby("Age")[["Country"]]

# %%
survey

# %%
schema = pd.read_csv('survey_results_schema.csv', index_col= "Column").QuestionText

# %%
schema
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
selected_columns = [
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'

]

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df = survey_raw_df[selected_columns].copy()

# %%
schema2 = schema[selected_columns]

# %%
schema2
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey_df["Age1stCode"] = pd.to_numeric(survey_df.Age1stCode, errors ="coerce")
survey_df["YearsCode"] = pd.to_numeric(survey_df.YearsCode, errors = "coerce")
survey_df["YearsCodePro"] = pd.to_numeric(survey_df.YearsCodePro, errors = "coerce")

# %%
survey_df.Age1stCode.unique()
# Out:
# array([13., 19., 15., 18., 16., 14., 12., 20., 42.,  8., 25., 22., 30.,
#        17., 21., 10., 46.,  9.,  7., 11.,  6., nan, 31., 29.,  5., 28.,
#        38., 23., 27., 41., 24., 53., 26., 35., 32., 40., 33., 36., 54.,
#        48., 56., 45., 44., 34., 39., 51., 68., 50., 37., 47., 43., 52.,
#        85., 64., 55., 58., 49., 76., 72., 73., 83., 63.])

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.Age1stCode < 10].index, inplace= True)
survey_df.drop(survey_df[survey_df.Age1stCode > 100].index, inplace = True)

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  41687.000000  52706.000000  52087.000000  40407.000000  37805.000000
# mean      30.643383     16.190415     12.188723      8.541243     40.760387
# std        9.553074      4.716308      9.141661      7.700690     17.884415
# min        1.000000     10.000000      1.000000      1.000000      1.000000
# 25%       24.000000     13.000000      6.000000      3.000000     40.000000
# 50%       29.000000     16.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     16.000000     11.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid")

# %%
top_countries= survey_df.Country.value_counts().head(15
                                                    )

# %%
top_countries
# Out:
# United States         11056
# India                  8202
# Germany                3569
# United Kingdom         3366
# Canada                 1993
# France                 1772
# Brazil                 1750
# Netherlands            1228
# Poland                 1179
# Spain                  1089
# Australia              1050
# Italy                  1036
# Russian Federation      994
# Pakistan                800
# Sweden                  792
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (12,6));
plt.xticks(rotation= 75);


sns.barplot(top_countries.index,top_countries);
# Out:
# C:\Users\91755\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(figsize= (12,6));
plt.xlabel("Age");
plt.ylabel("Number of responents")


plt.hist(survey_df.Age, bins =np.arange(10,80,5), color = "Blue")
# Out:
# (array([   93.,  2119.,  8834., 11568.,  8249.,  4818.,  2316.,  1463.,
#          1004.,   614.,   331.,   145.,    74.]),
#  array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75]),
#  <BarContainer object of 13 artists>)

# %%
 gender_count =survey_df.Gender.value_counts().head()

# %%
plt.pie(gender_count, labels= gender_count, autopct='%1.1f%%' );
plt.legend;

# %%
sns.countplot(x=survey_df.EdLevel);

plt.xticks(rotation=90);

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                  4169
# Developer, back-end                                                                                                                                                                                                                                                                                    2875
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                         2113
# ...

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_df = split_multicolumn(survey_df.DevType)

# %%
dev_df2 = dev_df.sum().sort_values(ascending = False)

# %%
dev_df2
# Out:
# Developer, full-stack                            24865
# Developer, back-end                              24856
# Developer, front-end                             16884
# Developer, desktop or enterprise applications    10636
# Developer, mobile                                 8768
# DevOps specialist                                 5224
# Database administrator                            5085
# Designer                                          4836
# System administrator                              4529
# Developer, embedded applications or devices       4187
# Data or business analyst                          3654
# Data scientist or machine learning specialist     3605
# Developer, QA or test                             3580
# Engineer, data                                    3401
# Academic researcher                               3216
# Educator                                          2602
# Developer, game or graphics                       2431
# ...

# %%
languages = split_multicolumn(survey_df.LanguageWorkedWith)

# %%
languages_per = languages.mean().sort_values(ascending = False) * 100

# %%
languages_per
# Out:
# JavaScript               59.808356
# HTML/CSS                 55.750997
# SQL                      48.448755
# Python                   38.437699
# Java                     35.732234
# Bash/Shell/PowerShell    28.239019
# C#                       27.483499
# PHP                      23.186585
# TypeScript               22.405937
# C++                      20.802761
# C                        18.939927
# Go                        7.434583
# Kotlin                    6.856636
# Ruby                      6.008979
# VBA                       5.345596
# Assembly                  5.214929
# Swift                     5.131169
# R                         5.030656
# Rust                      4.161222
# Dart                      3.497839
# Objective-C               3.494489
# Scala                     3.105840
# Perl                      2.584849
# Haskell                   1.794150
# Julia                     0.760545
# dtype: float64

# %%
sns.barplot(languages_per.index,languages_per);
plt.title("r")
plt.xlabel("count")
plt.figure(figsize=(12,6))
# Out:
# C:\Users\91755\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
